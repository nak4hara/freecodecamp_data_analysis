# %% [markdown]
# <a href="https://colab.research.google.com/github/nak4hara/freecodecamp_data_analysis/blob/main/freecodecamp_pandas_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data=[None],
                  index=[None],
                  columns=[None])

# %%
df
# Out:
#       NaN
# NaN  None

# %%
    marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

df_marvel = pd.DataFrame(data=marvel_data)

# %%
df_marvel
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ['name', 'sex', 'first_appearance']
df_marvel.columns = col_names
df_marvel
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
df_marvel.index = df_marvel['name']
df_marvel
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
df_marvel = df_marvel.drop(['name'], axis=1)
df_marvel
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
df_marvel = df_marvel.drop(['Namor'], axis= 0)

# %%
df_marvel = df_marvel.drop(['Hank Pym'], axis= 0)
df_marvel
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
df_marvel.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
df_marvel.tail()
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %%
df_marvel['sex'].head()
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
df_marvel['first_appearance'].iloc[1:-1,]
# Out:
# name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: first_appearance, dtype: int64

# %%
df_marvel.iloc[[0,-1]]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
#stopped right here
#DataFrame manipulation and operation
